# %%
import pandas as pd

#Load the dataset
df = pd.read_csv("Iris.csv")

#Separate the features (measurements) and the target variable (species)
x = df.drop("Species", axis=1) # Assuming your target column is named 'Species'
y = df["Species"]
